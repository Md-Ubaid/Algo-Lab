# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-Ubaid/Algo-Lab/blob/main/241B702_Lab_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MATRIX CHAIN MULTIPLICATION Dynamic Programming with table filling.
# Problem Description:
# Find minimum number of scalar multiplications needed to multiply a chain of matrices..

# %% [markdown]
# # Theory
# Cost of multiplying two matrices:
# If A is p×q and B is q×r, cost = p × q × r
#
# Dynamic Programming idea:
# Break problem into smaller subproblems.
# Store results in a table to avoid recomputation.
#
# m[i][j] = minimum cost to multiply Ai to Aj
#
# ## Algorithm
# 1. Take array p[] of size n
# 2. Create table m[n][n]
# 3. Set m[i][i] = 0
# 4. Fill table diagonally
# 5. For each chain length L:
#     Compute m[i][j]
#     Try all possible k between i and j
# 6. Choose minimum cost
# 7. Return m[1][n-1]

# %%
import sys

def matrix_chain_multiplication(p):
    n = len(p)

    # Create DP table
    m = [[0 for _ in range(n)] for _ in range(n)]

    # L is chain length
    for L in range(2, n):
        for i in range(1, n - L + 1):
            j = i + L - 1
            m[i][j] = sys.maxsize

            for k in range(i, j):
                cost = (m[i][k] +
                        m[k+1][j] +
                        p[i-1] * p[k] * p[j])

                if cost < m[i][j]:
                    m[i][j] = cost

    return m

# %%
# Input dimensions
p = [10, 30, 5, 60]

table = matrix_chain_multiplication(p)

print("Minimum multiplication cost:", table[1][len(p)-1])

print("\nDP Table:")
for row in table[1:]:
    print(row[1:])
# Out:
# Minimum multiplication cost: 4500
#
# DP Table:
# [0, 1500, 4500]
# [0, 0, 9000]
# [0, 0, 0]

# %% [markdown]
# # Exercise
# 1. Given p = [5, 10, 3, 12, 5, 50, 6]
# 2. Compute minimum cost
# 3. Print optimal parenthesization
# 4. Compare number of multiplications saved

# %%
import sys

def matrix_chain_multiplication(p):
    n = len(p)

    # Create DP table
    m = [[0 for _ in range(n)] for _ in range(n)]
    s = [[0 for _ in range(n)] for _ in range(n)]

    # L is chain length
    for L in range(2, n):
        for i in range(1, n - L + 1):
            j = i + L - 1
            m[i][j] = sys.maxsize

            for k in range(i, j):
                cost = (m[i][k] +
                        m[k+1][j] +
                        p[i-1] * p[k] * p[j])

                if cost < m[i][j]:
                    m[i][j] = cost
                    s[i][j] = k

    return m, s

# %%
import pandas as pd
p = [5, 10, 3, 12, 5, 50, 6]
m, k = matrix_chain_multiplication(p)
print("Minimum multiplication cost:", m[1][len(p)-1])
m_copy = pd.DataFrame(m)
print("\nDP Table:")
print(m_copy.iloc[1:,1:])
# Out:
# Minimum multiplication cost: 2010
#
# DP Table:
#    1    2    3    4     5     6
# 1  0  150  330  405  1655  2010
# 2  0    0  360  330  2430  1950
# 3  0    0    0  180   930  1770
# 4  0    0    0    0  3000  1860
# 5  0    0    0    0     0  1500
# 6  0    0    0    0     0     0

# %%
k_copy = pd.DataFrame(k)
print("\nK Table:")
print(k_copy.iloc[1:,1:])
# Out:
# K Table:
#    1  2  3  4  5  6
# 1  0  1  2  2  4  2
# 2  0  0  2  2  2  2
# 3  0  0  0  3  4  4
# 4  0  0  0  0  4  4
# 5  0  0  0  0  0  5
# 6  0  0  0  0  0  0

# %%
def optimal_parenthesization(s, i, j):
    if i == j:
        print(f"A{i}",end="")
        return
    print(f"(",end="")
    optimal_parenthesization(s, i, s[i][j])
    optimal_parenthesization(s, s[i][j]+1, j)
    print(f")",end="")

print("\nOptimal Parenthesization:")
optimal_parenthesization(k, 1, len(p)-1)
# Out:
# Optimal Parenthesization:
# ((A1A2)((A3A4)(A5A6)))

# %%
cost = 0
for i in range(1,len(p)-1):
    cost += p[0] * p[i] *p[i+1]

print("\nNumber of Multiplications saved:")
print(cost - m[1][len(p)-1])
# Out:
# Number of Multiplications saved:
# 1370
