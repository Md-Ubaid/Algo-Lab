# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-Ubaid/Algo-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %% [markdown]
# ### 1. Modify program for user input graph using dictionary.

# %%
def inputGraph():
  graph = {}
  nodes = list(input("Enter nodes ex: A B C ... :").split())
  for i in range(len(nodes)):
    graph[nodes[i]] = {}

  num_edges = int(input("Enter the number of edges: "))

  for i in range(num_edges):
    u, v, w = input(f"Enter edge {i+1} (format: source destination weight): ").split()
    graph[u][v] = int(w)
    graph[v][u] = (w)

  return graph

# %%
newGraph = inputGraph()
print(f"User input graph\n{newGraph}")
# Out:
# Enter nodes ex: A B C ... :A B C D
# Enter the number of edges: 5
# Enter edge 1 (format: source destination weight): A B 1
# Enter edge 2 (format: source destination weight): A D 2
# Enter edge 3 (format: source destination weight): B C 5
# Enter edge 4 (format: source destination weight): B D 4
# Enter edge 5 (format: source destination weight): C D 3
# User input graph
# {'A': {'B': 1, 'D': 2}, 'B': {'A': '1', 'C': 5, 'D': 4}, 'C': {'B': '5', 'D': 3}, 'D': {'A': '2', 'B': '4', 'C': '3'}}

# %% [markdown]
# ### 2. Display shortest path with total distance.

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')
total = 0
for node in result:
  total += result[node]
  print("Distance from A to", node, "=", result[node])
print(f"Total Distance: {total}")
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5
# Total Distance: 11

# %% [markdown]
# ### 3. Add two more nodes in graph.

# %%
graph_2 = {
'A': {'B': 3, 'E': 7},
'B': {'A': 3, 'C': 1, 'F': 15},
'C': {'B': 1, 'D': 4, 'F': 9},
'D': {'C': 4, 'E': 2, 'F': 3},
'E': {'A': 7, 'D': 2, 'F': 8},
'F': {'B': 15, 'C': 9, 'D': 3, 'E': 8}
}

# %% [markdown]
# ### 4. Test algorithm with different source nodes.

# %%
result = dijkstra(graph_2, 'A')
total = 0
for node in result:
  total += result[node]
  print("Distance from A to", node, "=", result[node])
print(f"Total Distance: {total}")
# Out:
# Distance from A to A = 0
# Distance from A to B = 3
# Distance from A to C = 4
# Distance from A to D = 8
# Distance from A to E = 7
# Distance from A to F = 11
# Total Distance: 33

# %%
result = dijkstra(graph_2, 'B')
total = 0
for node in result:
  total += result[node]
  print("Distance from A to", node, "=", result[node])
print(f"Total Distance: {total}")
# Out:
# Distance from A to A = 3
# Distance from A to B = 0
# Distance from A to C = 1
# Distance from A to D = 5
# Distance from A to E = 7
# Distance from A to F = 8
# Total Distance: 24

# %%
result = dijkstra(graph_2, 'C')
total = 0
for node in result:
  total += result[node]
  print("Distance from A to", node, "=", result[node])
print(f"Total Distance: {total}")
# Out:
# Distance from A to A = 4
# Distance from A to B = 1
# Distance from A to C = 0
# Distance from A to D = 4
# Distance from A to E = 6
# Distance from A to F = 7
# Total Distance: 22

# %%
result = dijkstra(graph_2, 'D')
total = 0
for node in result:
  total += result[node]
  print("Distance from A to", node, "=", result[node])
print(f"Total Distance: {total}")
# Out:
# Distance from A to A = 8
# Distance from A to B = 5
# Distance from A to C = 4
# Distance from A to D = 0
# Distance from A to E = 2
# Distance from A to F = 3
# Total Distance: 22

# %%
result = dijkstra(graph_2, 'E')
total = 0
for node in result:
  total += result[node]
  print("Distance from A to", node, "=", result[node])
print(f"Total Distance: {total}")
# Out:
# Distance from A to A = 7
# Distance from A to B = 7
# Distance from A to C = 6
# Distance from A to D = 2
# Distance from A to E = 0
# Distance from A to F = 5
# Total Distance: 27

# %%
result = dijkstra(graph_2, 'F')
total = 0
for node in result:
  total += result[node]
  print("Distance from A to", node, "=", result[node])
print(f"Total Distance: {total}")
# Out:
# Distance from A to A = 11
# Distance from A to B = 8
# Distance from A to C = 7
# Distance from A to D = 3
# Distance from A to E = 5
# Distance from A to F = 0
# Total Distance: 34
